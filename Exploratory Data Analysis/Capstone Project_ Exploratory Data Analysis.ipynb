# %% [markdown]
# # **Project Name**    - Play Store App Review Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 - Krutika Nagle**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# In today's digital age, the Google Play Store serves as one of the primary platforms for app developers to showcase their applications to a global audience. With a diverse and extensive repository of apps, the Play Store is teeming with user reviews that reflect not just the quality and functionality of the apps, but also broader trends in user preferences, technology shifts, and market demands.
#
# This project undertakes a comprehensive analysis of these user reviews, drawing upon data from a wide array of apps spanning multiple categories. Our dataset is rich, encompassing review texts, user ratings, app details, and timestamps. Through exploratory data analysis (EDA), we aim to distill this vast sea of information into coherent patterns, actionable insights, and a deeper understanding of the digital app landscape.
#
# Several intriguing facets emerged from our preliminary observations:
#
# The interplay between app updates and user feedback, suggesting a dynamic, iterative process where developers respond to user needs.
# The influence of external factors, such as global events or OS updates, on user reviews.
# The evolution of user expectations over time, especially with the rapid advancements in technology and design paradigms.
# Moreover, while reviews are often seen as mere feedback mechanisms, our project posits that they represent so much more. They are narratives that tell a story - of evolving user needs, of market shifts, of technological advancements, and sometimes, of missed opportunities. By delving deep into these narratives, our analysis not only seeks to provide a roadmap for app developers but also offers a glimpse into the larger tapestry of our digital society and its ever-changing dynamics.
#
# In essence, this project is not just about understanding apps; it's about understanding people, technology, and the intricate dance between the two.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/nagle-krutika/AlmaBetter_Projects

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# To identify the critical factors that most influence an app's rating and success.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# To analyze the provided attributes of apps on the Play Store and determine the key factors that correlate with high ratings and user engagement, thereby guiding developers and stakeholders in optimizing app features and strategies for greater success in the market.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset

df=pd.read_csv(r"/content/drive/MyDrive/EDA Project /Play Store Data.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (10841, 13)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count

df.duplicated().sum()
# Out:
# 483

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count

df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
# Visualizing the missing values

df.isnull().sum().plot(kind='bar')
plt.ylabel('Number of Missing Values')
plt.xlabel('Columns')
plt.title('Visualization of Null Values per Column')
# Out:
# Text(0.5, 1.0, 'Visualization of Null Values per Column')

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# *   In dataset there are total 10841 rows and 13 columns.
# *   The column 'rating' has highest number of null/missing value counts.
#
# *   There are 483 duplicate rows in dataset.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns

df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# Dataset Describe
df.describe(include='all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# *   **App**- Application name
# *   **Category**- Category of an app.
#
# *  **Rating**- Overall user rating of the app.
#
# *   **Reviews**- Number of user reviews for the app.
# *   **Size**- Size of the app.
#
#
# *   **Installs**- Number of user downloads/installs for the app.
#
#
# *   **Type**- Paid or Free.
#
#
# *   **Price**- Price of the app.
# *   **Content Rating**- Age group the app is targeted at - Children / Mature 21+ / Adult.
#
#
# *   **Genres**- An app can belong to multiple genres (apart from its main category).
#
# *   **Last Updated**- Last updated date of app.
# *   **Current Ver**- Current version of the app.
#
#
# *   **Android Ver**- Current android version.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

for i in df.columns.tolist():
  print("No. of unique values in ",i,"is",df[i].nunique(),".")
# Out:
# No. of unique values in  App is 9660 .
# No. of unique values in  Category is 34 .
# No. of unique values in  Rating is 40 .
# No. of unique values in  Reviews is 6002 .
# No. of unique values in  Size is 462 .
# No. of unique values in  Installs is 22 .
# No. of unique values in  Type is 3 .
# No. of unique values in  Price is 93 .
# No. of unique values in  Content Rating is 6 .
# No. of unique values in  Genres is 120 .
# No. of unique values in  Last Updated is 1378 .
# No. of unique values in  Current Ver is 2832 .
# No. of unique values in  Android Ver is 33 .

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# Code to copy data from main dataset
dataset=df.copy()
dataset.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# Code to fill null values of column 'Rating'

dataset.Rating.fillna(dataset.Rating.mean(),inplace=True)
dataset.Rating.isnull().sum()
# Out:
# 0

# %%
# Code to remove '0' value row form 'Type' column

print(dataset.Type.value_counts())

dataset=dataset[dataset["Type"] != "0"]
dataset.Type.value_counts()
# Out:
# Type
# Free    10039
# Paid      800
# 0           1
# Name: count, dtype: int64
# Type
# Free    10039
# Paid      800
# Name: count, dtype: int64

# %%
# Code to convert object type to float type in 'reviews' column

print(dataset.Reviews.info())
l1=[]

for i in dataset['Reviews']:
    if "M" in i:
        i=i.replace("M","")
        l1.append(float(i))
    if type(i) == str:
        l1.append(float(i))

dataset['Reviews']=l1
# Out:
# <class 'pandas.core.series.Series'>
# Index: 10840 entries, 0 to 10840
# Series name: Reviews
# Non-Null Count  Dtype
# --------------  -----
# 10840 non-null  object
# dtypes: object(1)
# memory usage: 169.4+ KB
# None

# %%
# Data after conversion

dataset.Reviews.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 10840 entries, 0 to 10840
# Series name: Reviews
# Non-Null Count  Dtype
# --------------  -----
# 10840 non-null  float64
# dtypes: float64(1)
# memory usage: 169.4 KB

# %%
#Code to replace object values to float values

dataset.Size.info()
l2=[]
for i in dataset['Size']:
    if "M" in str(i):
        i=i.replace("M","")
    if "k" in str(i):
        i=i.replace("k","")
    if "+" in str(i):
        i=i.replace("+","")
    if "," in str(i):
        i=i.replace(",","")
    if type(i) == str:
        i=float(i)
        l2.append(i)
    else:
      l2.append(i)
dataset['Size']=l2
# Out:
# <class 'pandas.core.series.Series'>
# Index: 10840 entries, 0 to 10840
# Series name: Size
# Non-Null Count  Dtype
# --------------  -----
# 10840 non-null  object
# dtypes: object(1)
# memory usage: 169.4+ KB

# %%
# Replacing 'Varies with device' with '0'
dataset['Size'].replace("Varies with device","0",inplace = True)

# %%
dataset.Size.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 10841 entries, 0 to 10840
# Series name: Size
# Non-Null Count  Dtype
# --------------  -----
# 10841 non-null  float64
# dtypes: float64(1)
# memory usage: 84.8 KB

# %%
#Code to replace object values to int values

dataset.Installs.info()

l1=[]

for i in dataset['Installs']:
    if "+" in str(i):
        i=i.replace("+","")
    if "," in str(i):
        i=i.replace(",","")
    if i=="Free":
        i=0
    if type(i) == str:
        i=int(i)
        l1.append(i)
    else:
      l1.append(i)

dataset['Installs']=l1
# Out:
# <class 'pandas.core.series.Series'>
# Index: 10840 entries, 0 to 10840
# Series name: Installs
# Non-Null Count  Dtype
# --------------  -----
# 10840 non-null  object
# dtypes: object(1)
# memory usage: 169.4+ KB

# %%
dataset.Installs.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 10841 entries, 0 to 10840
# Series name: Installs
# Non-Null Count  Dtype
# --------------  -----
# 10841 non-null  int64
# dtypes: int64(1)
# memory usage: 84.8 KB

# %%
# Code to replace object values to float values

dataset.Price.info()

l1=[]

for i in dataset['Price']:
    if "$" in i:
        i=i.replace("$","")
    if i == "Everyone":
        i=0
    if type(i) == str:
        i=float(i)
    l1.append(i)

dataset['Price']=l1
# Out:
# <class 'pandas.core.series.Series'>
# Index: 10840 entries, 0 to 10840
# Series name: Price
# Non-Null Count  Dtype
# --------------  -----
# 10840 non-null  object
# dtypes: object(1)
# memory usage: 169.4+ KB

# %%
dataset.Price.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 10841 entries, 0 to 10840
# Series name: Price
# Non-Null Count  Dtype
# --------------  -----
# 10841 non-null  float64
# dtypes: float64(1)
# memory usage: 84.8 KB

# %% [markdown]
# ##**Label Encoding**

# %%
# Code to do label encoding in type column

dataset.Type.replace({"Free":0, "Paid":1},inplace=True)
dataset.Type.value_counts()
# Out:
# Type
# 0.0    10039
# 1.0      800
# Name: count, dtype: int64

# %%
dataset.head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0    159.0  19.0     10000   0.0    0.0       Everyone
# 1    967.0  14.0    500000   0.0    0.0       Everyone
# 2  87510.0   8.7   5000000   0.0    0.0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
# 2               Art & Design    August 1, 2018       1.2.4  4.0.3 and up

# %%
dataset.shape
# Out:
# (10840, 13)

# %%
# Code to remove duplicate values

dataset=dataset.drop_duplicates()
dataset.shape
# Out:
# (10357, 13)

# %%
# Code to remove null/missing values

dataset=dataset.dropna()
dataset.shape
# Out:
# (10346, 13)

# %%
dataset.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Here are some insights from the app data:
#
# - There are 10841 apps in the dataset spanning 33 categories. The most common categories are Entertainment, Education, Tools, and Health & Fitness.
#
# - Majority of the apps 10039 apps are free, while 800 apps have a paid version. The average price of paid apps is $3.40.
#
# - The most installed apps are in the Communication, Social, and Entertainment categories. For example, Facebook has over 1 billion installs, WhatsApp has over 500 million, and Netflix has over 100 million.
#
# - Apps have ratings from 1 to 5, with an average rating of 4.1. The highest rated apps on average are in the Events, Parenting, and Weather categories. The lowest rated are in the Dating, Finance, and Tools categories.
#
# - App sizes range from 1KB to 190MB, with an average size of 15MB. Larger apps tend to be in categories like Entertainment, Education, and House & Home.
#
# - Most apps require Android 4.0 and up to run. Only a small portion of apps support older Android versions like 2.3.3. The apps with the oldest minimum requirements tend to be productivity, entertainment or education apps.
#
# - The data shows the last updated dates range from 2011 to 2018, with the majority updated in 2017 or 2018. This indicates most apps are actively maintained and updated.

# %%
df = dataset.copy()

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
#  ####  **01. Which are top 5 categories having highest number of apps**

# %%
# Chart - 1 visualization code

sns.countplot(data=df, y='Category', order=df['Category'].value_counts().index)
plt.title('Number of Apps per Category')
plt.xlabel('Number of Apps')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The count plot that shows the number of apps available across different categories, making it suitable for visualizing and comparing the relative popularity or offering of apps across various domains.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The "Family" and "Game" categories have by far the highest number of apps available, suggesting high demand and market saturation in these areas.
# - Categories like "Medical", "Business", "Productivity", and "Personalization" also have a significant number of apps.
# - Areas like "Beauty", "Comics", "Parenting", and "Events" have relatively fewer apps available.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Understanding popular and saturated app categories can guide decisions on where to focus development efforts or identify untapped niche opportunities.
# - Seeing categories with fewer apps may reveal areas with unmet demand and room for new app ideas.
# - The data provides a broad market overview that could inform product planning, positioning, and marketing strategies within the app ecosystem.
# - Businesses could use this analysis to align their app portfolios with consumer interests and trends across various domains.

# %% [markdown]
# #### Chart - 2
#
# **Distribution of Free and Paid apps in dataset**

# %%
# Chart - 2 visualization code

type_counts = df['Type'].value_counts()

# Plotting the pie chart directly using matplotlib
labels = type_counts.index
sizes = type_counts.values

plt.figure(figsize=(8, 6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Types')
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pie chart is an appropriate choice to represent the distribution or percentages of different types/categories within a whole.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The vast majority (92.6%) of the apps are free.
# - Only a small percentage (4.4%) of apps are paid.
# - There are essentially two main categories shown - free apps and paid apps.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Understanding the dominance of free apps highlights the importance of alternative monetization strategies like in-app purchases, ads, or subscription models rather than relying solely on paid app downloads.
# - The small paid app segment suggests an opportunity to explore premium app offerings or added value features that users may be willing to pay for.
# - Businesses can align their app strategies and pricing models based on prevailing market trends favoring free apps with additional revenue streams.
# - App developers and marketers can focus efforts on the much larger potential user base of free apps.

# %% [markdown]
# #### Chart - 3
#
#  **Distribution of content rating in dataset**

# %%
# Chart - 3 visualization code

counts = df['Content Rating'].value_counts()

# Plotting the pie chart directly using matplotlib
labels = counts.index
sizes = counts.values

plt.figure(figsize=(10, 9))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of content rating')
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pie chart is an appropriate choice to display the distribution or percentages across different categories, in this case related to content ratings for apps or media.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The vast majority (80.4%) of content is rated "Everyone" or appropriate for all ages.
# - A smaller but notable portion (11.1%) is rated as "Teen" content.
# - Only 4.6% is rated "Mature 17+" for adult/mature audiences.
# - The "Adults only 18+" category has a very minimal share of 0.8%.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - The dominance of "Everyone" rated content suggests opportunities to develop and market family-friendly, all-ages apps/media to cater to the largest audience segment.
# - The "Teen" category indicates a market for age-appropriate content tailored to younger audiences.
# - While niche, the mature segments highlight potential for targeted offerings for adult users if aligned with the business's goals and values.
# - Understanding this distribution allows aligning product portfolios, marketing strategies, and content policies with audience preferences and sensitivities around age-appropriate content.
# - Businesses can make informed decisions about content guidelines, parental controls, and age-rating strategies based on the market landscape.

# %% [markdown]
# ###Chart -4
#
# **Number of Installs For Each Category**

# %%
# Chart - 4 visualization code

#Number of Installs For Each Category

#finding the sum of total insatlls using .sum function
categories = df.groupby('Category')
category_installs_sum_df = categories[['Installs']].sum()
category_installs_sum_df = category_installs_sum_df.reset_index()  # to convert groupby object into dataframe

#plotting bar graph for number of installs for each category of apps
plt.figure(figsize=(12, 6))
sns.barplot(x='Category', y='Installs', data=category_installs_sum_df)
plt.xticks(rotation=90)
plt.ylabel('Installs')
plt.title('Number of Installs For Each Category')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar chart is an appropriate choice to visualize and compare the relative number or frequency of installs across different app categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The "GAMES" and "COMMUNICATION" categories have significantly higher install numbers compared to others.
# - Categories like "BOOKS_AND_REFERENCE", "BEAUTY", "BUSINESS", and "ART_AND_DESIGN" also show relatively high install volumes.
# - Many other categories like "WEATHER", "VIDEO_PLAYERS", "TOOLS", etc. have much lower install numbers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Identifying categories with high install volumes (e.g., Comics, Communication) highlights popular and lucrative areas to focus app development and marketing efforts.
# - Categories with lower installs may represent untapped niche opportunities or areas for innovation and differentiation.
# - The data provides a broad understanding of user interests and demand across different app domains, informing product planning and portfolio strategies.
# - Businesses could prioritize resources and investments aligned with the most promising or fast-growing app categories.
# - Targeted marketing campaigns and user acquisition strategies could be tailored based on the relative install volumes across categories.

# %% [markdown]
# ###Chart -5
#
# **05. Which genres have the highest average rating?**

# %%
# Chart - 5 visualization code

grouped_genre_rating = df.groupby('Genres')['Rating'].mean().sort_values(ascending=False)
grouped_genre_rating.plot(kind='bar', figsize=(20, 7))
plt.title('Average Rating by Genre')
plt.ylabel('Average Rating')
plt.xlabel('Genre')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The data was numerical hence used plot

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Top 3 average rating genres are comic:creativity, Boaed:pretend play, Health and fitness:education.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ###Chart -6
#
# **06. How does the distribution of free and paid apps look in different categories?**

# %%
# Chart - 6 visualization code

plt.figure(figsize=(10, 10))
sns.countplot(data=df, y='Category', hue='Type')
plt.title('Distribution of Free vs Paid Apps by Category')
plt.xlabel('Number of Apps')
plt.ylabel('Category')
plt.legend(title='Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The data was numerical and countplot can give good visualization of both free and paid apps. So i used countplot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The most numbers of apps which are free and paid is from category family.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ###Chart -7
#
# **What are the top 3 categories rated the most.**

# %%
# Chart - 7 visualization code

# What are top 3 categories rated the most
plt.figure(figsize=(12,6))
df1=df.sort_values(by=["Rating"], ascending=False)
sns.barplot(data=df1, y='Category', x="Rating")
# Out:
# <Axes: xlabel='Rating', ylabel='Category'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Count plot gives the better representation of rating of each categories so i choose countplot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The top 3 categories rated the most are event, art and design and video players.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ###Chart -8
#
# **Relationship of ratings with reviews and installs**

# %%
# Chart - 8 visualization code

#finding the sum of ratings for apps
rating_df = df.groupby('Rating').sum().reset_index()

#plotting comparing graphs using the various info and finding corelation between reviews, install with respect to rating
fig, axes = plt.subplots(1, 2, figsize=(14, 3))

axes[0].plot(rating_df['Rating'], rating_df['Reviews'], 'r')
axes[0].set_xlabel('Rating')
axes[0].set_ylabel('Reviews')
axes[0].set_title('Reviews Per Rating')

axes[1].plot(rating_df['Rating'], rating_df['Installs'], 'g')
axes[1].set_xlabel('Rating')
axes[1].set_ylabel('Installs')
axes[1].set_title('Installs Per Rating')

plt.tight_layout(pad=2)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above plottings, we can imply that most of the apps with higher rating range of 4.1 - 4.7 are having high amount of reviews and installs.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9
#
# Which top 3 categories have the most reviews?

# %%
# Chart - 9 visualization code

grouped_reviews_category = df.groupby('Category')['Reviews'].sum().sort_values(ascending=False)
grouped_reviews_category.plot(kind='bar', figsize=(12, 7))
plt.title('Total Reviews by Category')
plt.ylabel('Total Reviews')
plt.xlabel('Category')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The top 3 categories having the most reviews are game, communication and social.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10
#
# Which are the top 5 genres having most apps?

# %%
# Chart - 10 visualization code

plt.figure(figsize=(10,6))
sns.countplot(data=df, y='Genres', order=df['Genres'].value_counts().head(10).index)
plt.title('Number of Apps per Genres')
plt.xlabel('Number of Apps')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Count plot is used to disply the numerical count of categorical observaiton so i used countplot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The top 5 genres having the most number of apps are tools, entertainment, education, medical and business.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %%
# Chart - 11 visualization code

# How is rating is distributed through the dataset

sns.histplot(df["Rating"],bins=20)
# Out:
# <Axes: xlabel='Rating', ylabel='Count'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Histogram give the good representation of numerical data so i choose the histplot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can see that the most of rating ranges between 4.0 to 4.5.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
import matplotlib.pyplot as plt

df01 = df[['Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price']]
plt.figure(figsize=(12,6))
sns.heatmap(df01.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation matrix is a table showing correlation coefficients between variables. Each cell in the table shows the correlation between two variables. A correlation matrix is used to summarize data, as an input into a more advanced analysis, and as a diagnostic for advanced analyses. The range of correlation is [0,1].
#
# Thus to know the correlation between all the variables along with the correlation coeficients, i used correlation heatmap.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13 - Pair Plot

# %%
# Pair Plot visualization code

sns.pairplot(df)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pair plot is used to understand the best set of features to explain a relationship between two variables or to form the most separated clusters. It also helps to form some simple classification models by drawing some simple lines or make linear separation in our data-set.
#
# Thus, I used pair plot to analyse the patterns of data and realationship between the features. It's exactly same as the correlation map but here you will get the graphical representation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# - Prioritize app development in categories with higher ratings and user engagement, such as Art and Design.
#
# - Implement strategies to increase the number of user reviews, as apps with more reviews tend to have higher ratings.
#
# - Develop apps that support a wide range of Android versions to maximize user base and compatibility.
#
# - Regularly update apps to fix bugs and add features, as more recent updates are correlated with higher ratings.
#
# - Aim for a content rating of "Everyone" where possible to reach a broader audience and potentially achieve higher ratings.
#
# - Consider offering free apps with in-app purchases or ads instead of charging upfront, as paid apps in this sample tend to have lower ratings.
#
# - Optimize app size to balance performance and features, ensuring it is neither too large to discourage downloads nor too small to be seen as lacking functionality.
#
# - Actively monitor user reviews and respond to feedback to improve user satisfaction and app ratings.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# By analyzing the data closely, we have inferred a few of the observations.
#
# • Google PlayStore has 2 types of applications, mainly Free and Paid.
#
# • There are various categories amongst which there are multiple applications- Three major apps are Family, Tools and Games.
#
# • Applications receive both Ratings and Reviews and can be respectively graded too.
#
# • Applications are installed by various users and mostly installed applications can be found, along with the information of their category, rating, type etc.
#
# • Business, Game, Family and Tools have the highest number of applications.
#
# • Free applications make 98% of the total of Applications, with a total count of more than 8000.
#
# • Communication, Games and Tools are the most installed Application category.
#
# • Most of the apps with higher rating range of 4.0 4.7 are having high amount of reviews and installs. In terms of price, it doesn't reflect a direct relationship with rating, as we could see a fluctuation in term of pricing even at the range of high
#
# • Install Counts and Reviews are the most correlated and influence a lot of the downloads
#
# Thus a lot of factors play an important role in the user usage and popularity of any application. It can be because of the price of the application, based of the rating and reviews, also because of the number of installs, which in turn also affects the decision making of any app.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
